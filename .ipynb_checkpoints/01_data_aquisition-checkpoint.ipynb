# %%
import pandas as pd

# Define the file path
file_path = "data/GEOM_mosaec-db.csv"

# Load the CSV file into a pandas DataFrame
df_geom = pd.read_csv(file_path)

# Display the first few rows to verify it loaded correctly
print("\nDataFrame Shape:", df_geom.shape)
print("\nFirst 5 rows:")
print(df_geom.head())

# Check shape
if df_geom.shape == (124469, 24):
    print("\nSuccessfully Loaded! -> Proceed to 02_EDA_featurization....\n")
else:
    print("\nERROR: Shape does not match expected size!!!\n")
# Out:
# DataFrame Shape: (124469, 24)
#
# First 5 rows:
#              cif  Unitcell_volume  Density  ASA_A^2  ASA_m^2/cm^3  ASA_m^2/g  \
# 0    SILGOJ_full          2039.67  1.99200    0.000          0.00       0.00
# 1    LIGHAM_full          4599.89  1.04911  639.593       1390.45    1325.36
# 2    XEXTUQ_full          1828.05  1.93086    0.000          0.00       0.00
# 3  YIDSAF01_full          7806.04  1.73711    0.000          0.00       0.00
# 4    YEPKEM_full          3006.58  1.20308    0.000          0.00       0.00
#
#    NASA_A^2  NASA_m^2/cm^3  NASA_m^2/g  Largest included sphere  ...  \
# 0    0.0000         0.0000      0.0000                  2.72655  ...
# 1   10.3297        22.4565     21.4052                  5.54788  ...
# 2    0.0000         0.0000      0.0000                  2.30872  ...
# 3    0.0000         0.0000      0.0000                  2.19166  ...
# 4    0.0000         0.0000      0.0000                  2.24105  ...
#
# ...
